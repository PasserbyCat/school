# %%
import numpy as np
import numpy.random as random
import scipy as sp
from pandas import Series, DataFrame
import pandas as pd
import os
import shutil
from PIL import Image

# %%
import keras

# %%
import sklearn
from keras.models import Sequential
from tensorflow import keras
import tensorflow.keras.utils as np_utils
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation, Conv2D, MaxPooling2D

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import utils
from tensorflow.keras.models import load_model

# %%
labels = pd.read_csv("label.csv")

# %%
path = "training"
download_path = "trainset"

# %%
train_filename = []
train_category = []

# %%
for i in range(219):
    file_list = labels[labels['category'] == int(i)]['filename'].values
    os.makedirs(download_path, exist_ok=True)
    current_count = 0
    for j in file_list:
        file = os.path.join(path,j)
        train_filename.append(j)
        train_category.append(i)
        img = Image.open(file)
        img1 = img.transpose(Image.FLIP_LEFT_RIGHT)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img1.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        img2 = img.transpose(Image.FLIP_TOP_BOTTOM)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img2.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        angle = random.randint(-180, 180)
        img3 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img3.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        angle = random.randint(-180, 180)
        img4 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img4.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        angle = random.randint(-180, 180)
        img5 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img5.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        angle = random.randint(-180, 180)
        img6 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img6.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        angle = random.randint(-180, 180)
        img7 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img7.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        angle = random.randint(-180, 180)
        img8 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img8.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        angle = random.randint(-180, 180)
        img9 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img9.save(new_name)
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        shutil.copy(file,download_path)

# %%
train_labels = pd.DataFrame({
    "filename":train_filename,
    "category":train_category
})
train_labels.to_csv('label_all.csv',index=False)

# %%
labels_all = pd.read_csv("label_all.csv")

x_train = []
y_train = []
x_test = []
y_test = []

def load_img():
    img_name = os.listdir("trainset")
    count_img=0
    for i in img_name:
        count_img+=1
        img_path = os.path.join("trainset",i)
        img = Image.open(img_path)
        img = img.resize((160, 160))
        if count_img%10 == 0:
            x_test.append((np.array(img)/255.0))
            y_test.append(labels_all[labels_all['filename']==i]['category'].values)
        else:
            x_train.append((np.array(img)/255.0))
            y_train.append(labels_all[labels_all['filename']==i]['category'].values)

load_img()

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)
y_train = utils.to_categorical(y_train,219)
y_test = utils.to_categorical(y_test,219)

# %%
model = tf.keras.applications.ResNet101V2(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=(160,160,3),
    pooling=None,
    classes=219,
    classifier_activation="softmax",
)
#model.summary()

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['acc'])
model.fit(x=x_train,y=y_train,batch_size=20,epochs=20,validation_split=0.2)

# %%
test_filename = []
test_category = []

# %%
img_name = os.listdir("D:/desktop/dataset/orchid_public_set(1)")

for i in img_name:
    test_img=[]
    img_path = os.path.join("D:/desktop/dataset/orchid_public_set(1)",i)
    img = Image.open(img_path)
    img = img.resize((160, 160))
    test_img.append((np.array(img)/255.0))
    test_img=np.array(test_img)
    result = resnet_model.predict(test_img)
    predict_class=np.argmax(result,axis=1)
    test_filename.append(i)
    test_category.append(predict_class[0])

# %%
img_name = os.listdir("D:/desktop/dataset/orchid_private_set(1)")
for i in img_name:
    test_img=[]
    img_path = os.path.join("D:/desktop/dataset/orchid_private_set(1)",i)
    img = Image.open(img_path)
    img = img.resize((160, 160))
    test_img.append((np.array(img)/255.0))
    test_img=np.array(test_img)
    result = resnet_model.predict(test_img)
    predict_class=np.argmax(result,axis=1)
    test_filename.append(i)
    test_category.append(predict_class[0])

# %%
submission = pd.DataFrame({
    "filename":test_filename,
    "category":test_category
})
submission.to_csv('submission.csv',index=False)

# %% [markdown]
# 以下非程式碼本身，僅用於做測試。

# %%
predict_class=np.argmax(result,axis=1)
predict_class
# Out:
# array([105], dtype=int64)

# %%
test_category.append(predict_class[0])

# %%
test_category
# Out:
# [105]

# %%
resnet_model = load_model('model/Model.h5')

# %%
labels = pd.read_csv("label.csv")

# %%
labels.head()
# Out:
#          filename  category
# 0  me3uqlixjn.jpg         0
# 1  5c0vsrdtpq.jpg         0
# 2  swixut5b3l.jpg         0
# 3  m0eqa926lo.jpg         0
# 4  5jr6x2y9p8.jpg         0

# %%
def get_image(row_id, root="training",types=0):
    """
    Converts an image number into the file path where the image is located, 
    opens the image, and returns the image as a numpy array.
    """
    filename = "{}".format(row_id)
    file_path = os.path.join(root, filename)
    download = "download/"
    download_path = os.path.join(download, "{}".format(types))
    os.makedirs(download_path, exist_ok=True)
    print(file_path)
    print(download_path)
    shutil.copy(file_path,download_path)
    #! cp file_path download_path
    #cmd = "cp file_path download_path"
    #os.system(cmd)
    #img = Image.open(file_path)
    #return np.array(img)
#cURR8SgyRz4wwx!  
#pvrqcjia961237

# %%
def show_image(file_id):
    dir_name = "download"
    file_list = os.listdir(os.path.join(dir_name,"{}".format(file_id)))
    for i in file_list[0:1]:
        print(i)
        img = Image.open(os.path.join(dir_name,"{}".format(file_id),i))
        img.show()

# %%
show_image(0)
# Out:
# 0_0.jpg

# %%
getdata = "download"
getdata_buffer = "test123"
buffer = "test"

# %%
dir_list = os.listdir(getdata_buffer)

# %%
import random
print(random.randint(-180, 180))
# Out:
# -158

# %%
for i in dir_list:
    path = os.path.join(getdata_buffer,i)
    download_path = os.path.join(getdata,i)
    file_list = labels[labels['category'] == int(i)]['filename'].values
    os.makedirs(download_path, exist_ok=True)
    current_count = 0
    for j in file_list:
        file = os.path.join(path,j)
        img = Image.open(file)
        img1 = img.transpose(Image.FLIP_LEFT_RIGHT)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img1.save(new_name)
        current_count += 1
        img2 = img.transpose(Image.FLIP_TOP_BOTTOM)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img2.save(new_name)
        current_count += 1
        angle = random.randint(-180, 180)
        img3 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img3.save(new_name)
        current_count += 1
        angle = random.randint(-180, 180)
        img4 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img4.save(new_name)
        current_count += 1
        angle = random.randint(-180, 180)
        img5 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img5.save(new_name)
        current_count += 1
        angle = random.randint(-180, 180)
        img6 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img6.save(new_name)
        current_count += 1
        angle = random.randint(-180, 180)
        img7 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img7.save(new_name)
        current_count += 1
        angle = random.randint(-180, 180)
        img8 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img8.save(new_name)
        current_count += 1
        angle = random.randint(-180, 180)
        img9 = img.rotate(angle)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img9.save(new_name)
        current_count += 1
        shutil.copy(file,download_path)

# %%
int(dir_list[0])
# Out:
# 0

# %%
shutil.rmtree("trainset")

# %%
for i in dir_list:
    path = os.path.join(getdata_buffer,i)
    file_list = labels[labels['category'] == int(i)]['filename'].values
    current_count = 50
    for j in file_list:
        file = os.path.join(path,j)
        #print(file)
        img = Image.open(file)
        img1 = img.rotate(45)
        new_name = os.path.join(path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img1.save(new_name)
        current_count += 1
        img2 = img.rotate(135)
        new_name = os.path.join(path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img2.save(new_name)
        current_count += 1
        img3 = img.rotate(225)
        new_name = os.path.join(path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img3.save(new_name)
        current_count += 1
        img4 = img.rotate(315)
        new_name = os.path.join(path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        img4.save(new_name)
        current_count += 1

# %%
file_list = labels[labels['category'] == int(dir_list[0])]['filename'].values

# %%
aa=file_list['filename'].values

# %%
filename = []
category = []
for i in dir_list:
    path = os.path.join(getdata,i)
    file_list = os.listdir(path)
    current_count = 0
    for j in file_list:
        filename.append(j)
        category.append(i)

# %%
submission = pd.DataFrame({
    "filename":filename,
    "category":category
})

# %%
submission.head()
# Out:
#    filename category
# 0   0_0.jpg        0
# 1   0_1.jpg        0
# 2  0_10.jpg        0
# 3  0_11.jpg        0
# 4  0_12.jpg        0

# %%
submission.to_csv('label_all.csv',index=False)

# %%
os.makedirs("trainset", exist_ok=True)

# %%
dir_list = os.listdir(getdata)

# %%
for i in dir_list:
    path = os.path.join(getdata,i)
    file_list = os.listdir(path)
    for j in file_list:
        file = os.path.join(path,j)
        shutil.copy(file,"trainset")

# %%
for i in dir_list:
    path = os.path.join(getdata,i)
    file_list = os.listdir(path)
    for j in file_list:
        file = os.path.join(path,j)
        new_dir = os.path.join(buffer,i)
        os.makedirs(new_dir, exist_ok=True)
        shutil.copy(file,new_dir)

# %%
batch_size = 10
img_arr = []

# %%
x_train = []
y_train = []
x_test = []
y_test = []

# %%
img_name = os.listdir("trainset")
img_name[0]
# Out:
# '02a91mzn84.jpg'

# %%
# Out:
#            filename  category
# 800  02a91mzn84.jpg       105

# %%
img = Image.open(img_path)

# %%
def load_img():
    img_name = os.listdir("trainset")
    count_img=0
    for i in img_name:
        count_img+=1
        img_path = os.path.join("trainset",i)
        img = Image.open(img_path)
        img = img.resize((160, 160))
        if count_img%10 == 0:
            x_test.append((np.array(img)/255.0))
            y_test.append(labels_all[labels_all['filename']==i]['category'].values)
        else:
            x_train.append((np.array(img)/255.0))
            y_train.append(labels_all[labels_all['filename']==i]['category'].values)

# %%
load_img()
#train_data = tf.data.Dataset.from_tensor_slices(img_arr).shuffle(batch_size*6).batch(batch_size).repeat()
#train_data_iter = iter(train_data)

# %%
#test_img = load_img()
len(x_train)
# Out:
# 19710

# %%
labels_all.head()
# Out:
#    filename  category
# 0   0_0.jpg         0
# 1   0_1.jpg         0
# 2  0_10.jpg         0
# 3  0_11.jpg         0
# 4  0_12.jpg         0

# %%
train_data = tf.data.Dataset.from_tensor_slices(img_arr).shuffle(batch_size*6).batch(batch_size).repeat()
train_data_iter = iter(train_data)

# %%
labels_all = pd.read_csv("label_all.csv")

# %%
buffer = "download_buffer"

# %%
dir_list = os.listdir(getdata)

# %%
current_count = 0

# %%
current_count
# Out:
# 0

# %%
dir_list[0:9]
# Out:
# ['0', '1', '10', '100', '101', '102', '103', '104', '105']

# %%
for i in dir_list:
    path = os.path.join(getdata,i)
    if os.path.isdir(path):
        shutil.rmtree(path)

# %%
for i in dir_list:
    path = os.path.join(getdata,i)
    file_list = os.listdir(path)
    current_count = 0
    for j in file_list:
        file = os.listdir(os.path.join(path,j))
        for k in file:
            file_name = os.path.join(path,j,k)
            new_name = os.path.join(path,j,"{}".format(current_count)) + ".jpg"
            current_count += 1
            os.rename(file_name,new_name)
            shutil.move(new_name,path)
        if len(os.listdir(os.path.join(path,j))) == 0:
            os.rmdir(os.path.join(path,j))

# %%
for i in dir_list:
    path = os.path.join(getdata,i)
    file_list = os.listdir(path)
    current_count = 0
    for j in file_list:
        file_name = os.path.join(path,j)
        name = "{}".format(i) + "_" + "{}".format(current_count) + ".jpg"
        new_name = os.path.join(path,name)
        current_count += 1
        os.rename(file_name,new_name)

# %%
for i in dir_list:
    path = os.path.join(getdata,i)
    file_list = os.listdir(path)
    for j in file_list:
        file_name = os.path.join(path,j)
        if os.path.isdir(os.path.join(path,j)):
            shutil.rmtree(file_name)

# %%
count = 0

# %%
for i in dir_list:
    if os.path.isdir(os.path.join(buffer,i)):
        file_list = os.listdir(os.path.join(getdata,i))
        file_dir = os.path.join(buffer,i)
        for j in range(0,len(file_list)):
            file_list[j] = file_list[j] + ".jpg"
        for j in file_list:
            if os.path.exists(os.path.join(file_dir,j)):
                os.makedirs(os.path.join(getdata_buffer,i), exist_ok=True)
                shutil.move(os.path.join(file_dir,j),os.path.join(getdata_buffer,i))
                count +=1
                if len(os.listdir(file_dir))==0:
                    os.rmdir(file_dir)

# %%
count
# Out:
# 90

# %%
file_counts = 0
test123_dirlist = os.listdir(getdata_buffer)

# %%
for i in test123_dirlist:
    test123_filelist = os.listdir(os.path.join(getdata_buffer,i))
    file_counts += len(test123_filelist)

# %%
file_counts
# Out:
# 2190

# %%
file_lost = 0
test123_dirlist = os.listdir(buffer)
for i in test123_dirlist:
    test123_filelist = os.listdir(os.path.join(buffer,i))
    file_lost += len(test123_filelist)
file_lost
# Out:
# 0

# %%
download = "download/"
download_path = os.path.join(download, "{}".format(0))

# %%
os.makedirs(download_path, exist_ok=True)

# %%
size = labels.category[-1]+1

# %%
arr = [[] for _ in range(size)]

# %%
download = "download/"
download_path = os.path.join(download, "{}".format(types))
os.makedirs(download_path, exist_ok=True)

# %%
for i in range(size):
    arr[i] = labels[labels.category == i].index
    for m in range(10):      
        #get_image(arr[i][m],types=i)
# Out:
#   File "C:\Users\asd95\AppData\Local\Temp/ipykernel_32808/1351957528.py", line 4
#     #get_image(arr[i][m],types=i)
#                                  ^
# IndentationError: expected an indented block

# %%
size
# Out:
# 219

# %%
labelset = []
for i in range(219):
    labelset.append("{}".format(i))

# %%
labelset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
labels_test = pd.read_csv("/content/drive/MyDrive/flowerDataset/label.csv")

# %%
train_filename = []
train_category = []
path = "training"
download_path = "trainset"

# %%
for i in range(1):
    file_list = labels_test[labels_test['category'] == int(i)]['filename'].values
    #os.makedirs(download_path, exist_ok=True)
    current_count = 0
    for j in file_list:
        train_filename.append(j)
        train_category.append(i)
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        new_filename = "{}".format(i) + "_" + "{}".format(current_count) +".jpg"
        print(new_filename)
        train_filename.append(new_filename)
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
        new_name = os.path.join(download_path,"{}".format(i)) + "_" + "{}".format(current_count) +".jpg"
        train_filename.append("{}".format(i) + "_" + "{}".format(current_count) +".jpg")
        train_category.append(i)
        current_count += 1
# Out:
# 0_0.jpg
# 0_9.jpg
# 0_18.jpg
# 0_27.jpg
# 0_36.jpg
# 0_45.jpg
# 0_54.jpg
# 0_63.jpg
# 0_72.jpg
# 0_81.jpg

# %%
test_labels = pd.DataFrame({
    "filename":train_filename,
    "category":train_category
})

# %%
test_labels.head()
# Out:
#          filename  category
# 0  me3uqlixjn.jpg         0
# 1         0_0.jpg         0
# 2         0_1.jpg         0
# 3         0_2.jpg         0
# 4         0_3.jpg         0
